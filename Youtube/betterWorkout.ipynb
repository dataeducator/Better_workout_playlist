# %% [markdown]
# #  Project: Using Data to Improve My Quality of Life
#
#
# During the pandemic, many of us began to focus on our personal health. I found myself as one among many of my friends who found time to work out, eat better, drink water and mind our business. However, after some of the restrictions were lifted, I found myself slipping back into older, less beneficial habits. This project is one of many in my pursuit of a better work life balance. I collected data on 10 of the youtube influencers I tried during the height of the pandemic and created a plan to craft a more sustainable plan for working out going forward. It was inspired by Thu Vu's Youtube API portfolio project and conversations with Soukina A. about my postpandemic sugar intake and general inactivity. </font>

# %%
# Warnings
import warnings
warnings.filterwarnings('ignore')
    
# import libraries and visualization packages
from googleapiclient.discovery import build
from dateutil import parser
import pandas as pd
import numpy as np
from PIL import Image 
from IPython.display import JSON
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# Data viz packages
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker


# NLP
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
nltk.download('stopwords')
nltk.download('punkt')
from wordcloud import WordCloud
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\tenic\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\tenic\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# Set the API Key and playlist information
api_key = '' # Key not shown here, please generate your own if you would like to implement this project
playlist_name = 'Better Workout'
playlist_description = 'A playlist of the best of my favorite fitness Youtubers'

# %%
# Set Channel IDs to 10 of the youtube channels choosing between for working out during the pandemic
channel_ids = ['UCCgLoMYIyP0U56dEhEL1wXQ',
               'UChVRfsT_ASBZk10o0An7Ucg',
               'UCpQ34afVgk8cRQBjSJ1xuJQ',
               'UCTsM1dSAiXqiV5oZjuNw_Bg',
               'UCIJwWYOfsCfz6PjxbONYXSg',
               'UCEQi1ZNJiw3YMRwni0OLsTQ',
               'UCvGEK5_U-kLgO6-AMDPeTUQ',
               'UCjfG0dyMUiqKleUnkX6zBrA',
               'UCRx0HAyAfmcqtrQYK3IITBA',
               'UCyqR7WkL8i1b6xtSssDmW9w',
              ]

# %%
api_service_name = "youtube"
api_version = "v3"

# Get credentials and create an API client
youtube = build(
    api_service_name, api_version, developerKey=api_key)

# %%
def get_channel_stats(youtube, channel_ids):
    
    """
    Get channel stats
    
    Params:
    ------
    youtube: build object of Youtube API
    channel_ids: list of channel IDs
    
    Returns:
    ------
    dataframe with all channel stats for each channel ID
    
    """
    
    all_data = []
    
    request = youtube.channels().list(
        part="snippet,contentDetails,statistics",
        id=','.join(channel_ids)
    )
    response = request.execute()

    # loop through items
    for item in response['items']:
        data = {'channelName': item['snippet']['title'],
                'subscribers': item['statistics']['subscriberCount'],
                'views': item['statistics']['viewCount'],
                'totalVideos': item['statistics']['videoCount'],
                'playlistId': item['contentDetails']['relatedPlaylists']['uploads']
        }
        
        all_data.append(data)
        
    return(pd.DataFrame(all_data))

# %%
def get_video_ids(youtube, playlist_id):
    """
    Get video ids
    
    Params:
    ------
    youtube: build object of Youtube API
    playlist_ids: list of video IDs
    
    Returns:
    ------
    list with all videos within a playlist
    
    """    
    video_ids = []
    
    request = youtube.playlistItems().list(
        part="snippet,contentDetails",
        playlistId=playlist_id,
        maxResults = 50
    )
    response = request.execute()
    
    for item in response['items']:
        video_ids.append(item['contentDetails']['videoId'])
        
    next_page_token = response.get('nextPageToken')
    while next_page_token is not None:
        request = youtube.playlistItems().list(
                    part='contentDetails',
                    playlistId = playlist_id,
                    maxResults = 50,
                    pageToken = next_page_token)
        response = request.execute()

        for item in response['items']:
            video_ids.append(item['contentDetails']['videoId'])

        next_page_token = response.get('nextPageToken')
        
    return video_ids

# %%
def get_video_details(youtube, video_ids):
    """
    Get video details
    
    Params:
    ------
    youtube: build object of Youtube API
    video_ids: list of video IDs
    
    Returns:
    ------
    dataframe with all video details for each video ID
    
    """
    all_video_info = []
    
    for i in range(0, len(video_ids), 50):
        request = youtube.videos().list(
            part="snippet,contentDetails,statistics",
            id=','.join(video_ids[i:i+50])
        )
        response = request.execute() 

        for video in response['items']:
            stats_to_keep = {'snippet': ['channelTitle', 'title', 'description', 'tags', 'publishedAt'],
                             'statistics': ['viewCount', 'likeCount', 'favouriteCount', 'commentCount'],
                             'contentDetails': ['duration', 'definition', 'caption']
                            }
            video_info = {}
            video_info['video_id'] = video['id']

            for k in stats_to_keep.keys():
                for v in stats_to_keep[k]:
                    try:
                        video_info[v] = video[k][v]
                    except:
                        video_info[v] = None

            all_video_info.append(video_info)
    
    return pd.DataFrame(all_video_info)

# %%
channel_stats = get_channel_stats(youtube, channel_ids)

# %%
channel_stats
# Out:
#                 channelName subscribers       views totalVideos  \
# 0                    MadFit     7150000   753386546         554
# 1                Chloe Ting    23900000  2701471621         364
# 2            Natacha Océane     1490000   136597249         215
# 3                  emi wong     5460000   697201308         418
# 4           Whitney Simmons     2080000   221215000         428
# 5                blogilates     6650000  1535957344        1027
# 6  Bret Contreras Glute Guy      370000    27708134         459
# 7               Pamela Reif     8920000  1480064256         168
# 8               Lilly Sabri     3790000   493700181         796
# 9      The Fitness Marshall     4070000   770844583         410
#
#                  playlistId
# 0  UUpQ34afVgk8cRQBjSJ1xuJQ
# 1  UUCgLoMYIyP0U56dEhEL1wXQ
# 2  UUjfG0dyMUiqKleUnkX6zBrA
# 3  UUvGEK5_U-kLgO6-AMDPeTUQ
# 4  UUEQi1ZNJiw3YMRwni0OLsTQ
# 5  UUIJwWYOfsCfz6PjxbONYXSg
# 6  UURx0HAyAfmcqtrQYK3IITBA
# 7  UUhVRfsT_ASBZk10o0An7Ucg
# 8  UUTsM1dSAiXqiV5oZjuNw_Bg
# 9  UUyqR7WkL8i1b6xtSssDmW9w

# %%
# Get Playlist IDs
playlist_id_0 = "UUEQi1ZNJiw3YMRwni0OLsTQ" # Whitney Simmons
playlist_id_1 = "UUvGEK5_U-kLgO6-AMDPeTUQ" # Emi Wong
playlist_id_2 = "UUTsM1dSAiXqiV5oZjuNw_Bg" # Lilly Sabri
playlist_id_3 = "UUjfG0dyMUiqKleUnkX6zBrA" # Natacha Océane
playlist_id_4 = "UURx0HAyAfmcqtrQYK3IITBA" # Brett Contreras Glute Guy
playlist_id_5 = "UUyqR7WkL8i1b6xtSssDmW9w" # The Fitness Marshall
playlist_id_6 = "UUCgLoMYIyP0U56dEhEL1wXQ" # Chloe Ting
playlist_id_7 = "UUpQ34afVgk8cRQBjSJ1xuJQ" # MadFit
playlist_id_8 = "UUIJwWYOfsCfz6PjxbONYXSg" # Blogilates
playlist_id_9 = "UUhVRfsT_ASBZk10o0An7Ucg" # Pamela Reif

# %%
# Get video IDs
video_ids_A = get_video_ids(youtube, playlist_id_0)# Whitney Simmons
video_ids_B = get_video_ids(youtube, playlist_id_1)# Emi Wong
video_ids_C = get_video_ids(youtube, playlist_id_2)# Lilly Sabri
video_ids_D = get_video_ids(youtube, playlist_id_3)# Natacha Océane
video_ids_E = get_video_ids(youtube, playlist_id_4)# Brett Contreras Glute Guy
video_ids_F = get_video_ids(youtube, playlist_id_5)# The Fitness Marshall
video_ids_G = get_video_ids(youtube, playlist_id_6)# Chloe Ting
video_ids_H = get_video_ids(youtube, playlist_id_7)# Mad Fit
video_ids_I = get_video_ids(youtube, playlist_id_8)# Blogilates
video_ids_J = get_video_ids(youtube, playlist_id_9)# Pamela Reif

# %%
# To determine the number of videos on each channel's default playlist use the following format
# length = len(video_ids_A)

# %%
# Get video details
video_df_A = get_video_details(youtube, video_ids_A)# Whitney Simmons
video_df_B = get_video_details(youtube, video_ids_B)# Emi Wong
video_df_C = get_video_details(youtube, video_ids_C)# Lilly Sabri
video_df_D = get_video_details(youtube, video_ids_D)# Brett Contreras Glute Guy
video_df_E = get_video_details(youtube, video_ids_E)# Brett Contreras Glute Guy
video_df_F = get_video_details(youtube, video_ids_F)# The Fitness Marshall
video_df_G = get_video_details(youtube, video_ids_G)# Chloe Ting
video_df_H = get_video_details(youtube, video_ids_H)# Mad Fit
video_df_I = get_video_details(youtube, video_ids_I)# Blogilates
video_df_J = get_video_details(youtube, video_ids_J)# Pamela Reif

video_df = pd.concat([video_df_A, video_df_B,video_df_C,video_df_D,video_df_E,video_df_F,video_df_G,video_df_H,video_df_I,video_df_J], axis=0)

# %%
video_df
# Out:
#         video_id     channelTitle  \
# 0    Uxux1MxDiZ8  Whitney Simmons
# 1    L4gMGVAM0KE  Whitney Simmons
# 2    n2Pu6Iai98o  Whitney Simmons
# 3    BJJhsmhpPGE  Whitney Simmons
# 4    RHPIdIAVyT0  Whitney Simmons
# ..           ...              ...
# 163  QN5Nu1aeYyc      Pamela Reif
# 164  RqfkrZA_ie0      Pamela Reif
# 165  Q-vuR4PJh2c      Pamela Reif
# 166  iY4hQd24_d0      Pamela Reif
# 167  5cMYysFl4CY      Pamela Reif
#
#                                                  title  \
# 0    ARE YOU READY FOR IT? REVEALING MY NEW GYMSHAR...
# 1    FAVORITES I NEVER WANT TO LIVE WITHOUT | Month...
# 2    GRWM as we FINALLY Talk Wedding Plans, Depress...
# 3         LET'S CHAT About NEW GYMSHARK! Haul + Try On
# 4    EVERYTHING I EAT IN A DAY! Healthy Meal & Snac...
# ..                                                 ...
# 163  SEXY ARMS IN 10 MIN  / No Equipment | Pamela Reif
# 164    10 MIN BOOTY BURN // No Equipment | Pamela Reif
# 165  10 MIN SIXPACK WORKOUT // No Equipment | Pamel...
# 166   5MIN BOOTY & AB WORKOUT // Yoga Ball | Pamela RF
# 167  10 MIN INTENSE AB WORKOUT // No Equipment | Pa...
#
#                                            description  \
# 0    GYMSHARK X WHITNEY SIMMONS\n\nLAUNCHING JUNE 2...
# 1    CURRENT MUST HAVE FAVORITES for Spring!\n\nSHO...
# 2    Get ready with me as we finally chat all thing...
# 3    Reviewing the BRAND NEW Gymshark Spring Releas...
# 4    FULL DAY OF EATING!\n\nTRAIN WITH ME on the Al...
# ..                                                 ...
# 163  This is an INTERMEDIATE workout with options f...
# 164  A quick & intense workout to target your butt....
# 165  NO EXCUSES ♥︎  a quick & intense workout to ta...
# 166  INTENSE BOOTY & AB EXERCISES //  QUICK & EFFEC...
# 167  QUICK & INTENSE.  NO EQUIPMENT NEEDED. NO EXCU...
#
#                                                   tags           publishedAt  \
# 0    [WHITNEY SIMMONS, GYMSHARK, COLLAB, WHITNEY X ...  2022-06-15T18:00:05Z
# 1    [WHITNEY SIMMONS, MONTHLY FAVORITES, MONTHLY M...  2022-05-29T19:29:12Z
# 2                                                 None  2022-05-18T18:41:29Z
# 3    [WHITNEY SIMMONS, GYMSHARK, REVIEW, HAUL, TRY ...  2022-03-10T17:19:15Z
# 4    [full day of eating, whitney simmons, everythi...  2022-03-01T16:00:11Z
# ..                                                 ...                   ...
# 163  [workout, training, arm, core, chest, back, up...  2018-03-15T15:08:41Z
# 164  [workout, training, butt, glute, booty, ass, l...  2018-01-30T15:12:13Z
# 165  [workout, training, abs, sickpack, flat, tummy...  2018-01-08T18:38:38Z
# 166  in, 5 minutes, workout, training, abs, ab w...  2016-07-21T20:21:57Z
# 167  [Workout, ab, home, fitness, sixpack, home wor...  2016-04-21T16:55:21Z
#
#     viewCount likeCount favouriteCount commentCount  duration definition  \
# 0      245289     11222           None         1688  PT20M31S         hd
# 1      179620      8952           None          661  PT14M23S         hd
# 2      196516      9980           None         1098  PT22M27S         hd
# 3      242675      8925           None          583  PT12M44S         hd
# 4      485789     19328           None          717  PT20M41S         hd
# ..        ...       ...            ...          ...       ...        ...
# 163  10392350    122927           None         1737  PT10M11S         hd
# 164  49544242    806265           None        16061  PT11M14S         hd
# 165  54115490    586081           None        12655  PT10M22S         hd
# 166   5257486     97809           None         1066   PT5M36S         hd
# 167  15537186    225320           None         4318   PT9M54S         hd
#
#     caption
# 0     false
# 1     false
# 2     false
# 3     false
# 4     false
# ..      ...
# 163   false
# 164   false
# 165   false
# 166   false
# 167   false
#
# [4842 rows x 13 columns]

# %% [markdown]
# ## Data Pre-processing

# %%
# Check Datatypes in Dataframe
video_df.dtypes
# Out:
# video_id          object
# channelTitle      object
# title             object
# description       object
# tags              object
# publishedAt       object
# viewCount         object
# likeCount         object
# favouriteCount    object
# commentCount      object
# duration          object
# definition        object
# caption           object
# dtype: object

# %%
# Convert Duration to seconds
import isodate
video_df['durationSecs'] = video_df['duration'].apply(lambda x : isodate.parse_duration(x))
video_df['duration_t'] = video_df['durationSecs'].astype('timedelta64[s]')

# Convert Duration to minutes
video_df['duration_m'] = video_df['durationSecs'].astype('timedelta64[s]')%60

# Compare Duration in minutes to original Duration object code
video_df[['duration_m', 'duration']] 

# Truncate the titles of videos to 25 characters
video_df['title'] = video_df['title'].str [:25] 

# Add tag count
video_df['tag_count'] = video_df['tags'].apply(lambda x:0 if x is None else len(x))
# Out:
#      duration_m  duration
# 0          31.0  PT20M31S
# 1          23.0  PT14M23S
# 2          27.0  PT22M27S
# 3          44.0  PT12M44S
# 4          41.0  PT20M41S
# ..          ...       ...
# 163        11.0  PT10M11S
# 164        14.0  PT11M14S
# 165        22.0  PT10M22S
# 166        36.0   PT5M36S
# 167        54.0   PT9M54S
#
# [4842 rows x 2 columns]

# %%
# Convert columns to numerical values
numeric_cols =['viewCount', 'likeCount', 'favouriteCount', 'duration_m','commentCount']
video_df[numeric_cols] = video_df[numeric_cols].apply(pd.to_numeric,errors = 'coerce', axis = 1)

# %%
video_df
# Out:
#         video_id     channelTitle                      title  \
# 0    Uxux1MxDiZ8  Whitney Simmons  ARE YOU READY FOR IT? REV
# 1    L4gMGVAM0KE  Whitney Simmons  FAVORITES I NEVER WANT TO
# 2    n2Pu6Iai98o  Whitney Simmons  GRWM as we FINALLY Talk W
# 3    BJJhsmhpPGE  Whitney Simmons  LET'S CHAT About NEW GYMS
# 4    RHPIdIAVyT0  Whitney Simmons  EVERYTHING I EAT IN A DAY
# ..           ...              ...                        ...
# 163  QN5Nu1aeYyc      Pamela Reif  SEXY ARMS IN 10 MIN  / No
# 164  RqfkrZA_ie0      Pamela Reif  10 MIN BOOTY BURN // No E
# 165  Q-vuR4PJh2c      Pamela Reif  10 MIN SIXPACK WORKOUT //
# 166  iY4hQd24_d0      Pamela Reif  5MIN BOOTY & AB WORKOUT /
# 167  5cMYysFl4CY      Pamela Reif  10 MIN INTENSE AB WORKOUT
#
#                                            description  \
# 0    GYMSHARK X WHITNEY SIMMONS\n\nLAUNCHING JUNE 2...
# 1    CURRENT MUST HAVE FAVORITES for Spring!\n\nSHO...
# 2    Get ready with me as we finally chat all thing...
# 3    Reviewing the BRAND NEW Gymshark Spring Releas...
# 4    FULL DAY OF EATING!\n\nTRAIN WITH ME on the Al...
# ..                                                 ...
# 163  This is an INTERMEDIATE workout with options f...
# 164  A quick & intense workout to target your butt....
# 165  NO EXCUSES ♥︎  a quick & intense workout to ta...
# 166  INTENSE BOOTY & AB EXERCISES //  QUICK & EFFEC...
# 167  QUICK & INTENSE.  NO EQUIPMENT NEEDED. NO EXCU...
#
#                                                   tags           publishedAt  \
# 0    [WHITNEY SIMMONS, GYMSHARK, COLLAB, WHITNEY X ...  2022-06-15T18:00:05Z
# 1    [WHITNEY SIMMONS, MONTHLY FAVORITES, MONTHLY M...  2022-05-29T19:29:12Z
# 2                                                 None  2022-05-18T18:41:29Z
# 3    [WHITNEY SIMMONS, GYMSHARK, REVIEW, HAUL, TRY ...  2022-03-10T17:19:15Z
# 4    [full day of eating, whitney simmons, everythi...  2022-03-01T16:00:11Z
# ..                                                 ...                   ...
# 163  [workout, training, arm, core, chest, back, up...  2018-03-15T15:08:41Z
# 164  [workout, training, butt, glute, booty, ass, l...  2018-01-30T15:12:13Z
# 165  [workout, training, abs, sickpack, flat, tummy...  2018-01-08T18:38:38Z
# 166  in, 5 minutes, workout, training, abs, ab w...  2016-07-21T20:21:57Z
# 167  [Workout, ab, home, fitness, sixpack, home wor...  2016-04-21T16:55:21Z
#
#       viewCount  likeCount  favouriteCount  commentCount  duration definition  \
# 0      245289.0    11222.0             NaN        1688.0  PT20M31S         hd
# 1      179620.0     8952.0             NaN         661.0  PT14M23S         hd
# 2      196516.0     9980.0             NaN        1098.0  PT22M27S         hd
# 3      242675.0     8925.0             NaN         583.0  PT12M44S         hd
# 4      485789.0    19328.0             NaN         717.0  PT20M41S         hd
# ..          ...        ...             ...           ...       ...        ...
# 163  10392350.0   122927.0             NaN        1737.0  PT10M11S         hd
# 164  49544242.0   806265.0             NaN       16061.0  PT11M14S         hd
# 165  54115490.0   586081.0             NaN       12655.0  PT10M22S         hd
# 166   5257486.0    97809.0             NaN        1066.0   PT5M36S         hd
# 167  15537186.0   225320.0             NaN        4318.0   PT9M54S         hd
#
#     caption    durationSecs  duration_t  duration_m  tag_count
# 0     false 0 days 00:20:31      1231.0        31.0          7
# 1     false 0 days 00:14:23       863.0        23.0          5
# 2     false 0 days 00:22:27      1347.0        27.0          0
# 3     false 0 days 00:12:44       764.0        44.0          6
# 4     false 0 days 00:20:41      1241.0        41.0          4
# ..      ...             ...         ...         ...        ...
# 163   false 0 days 00:10:11       611.0        11.0         46
# 164   false 0 days 00:11:14       674.0        14.0         48
# 165   false 0 days 00:10:22       622.0        22.0         48
# 166   false 0 days 00:05:36       336.0        36.0         37
# 167   false 0 days 00:09:54       594.0        54.0         29
#
# [4842 rows x 17 columns]

# %%
video_df.dtypes
# Out:
# video_id                   object
# channelTitle               object
# title                      object
# description                object
# tags                       object
# publishedAt                object
# viewCount                 float64
# likeCount                 float64
# favouriteCount            float64
# commentCount              float64
# duration                   object
# definition                 object
# caption                    object
# durationSecs      timedelta64[ns]
# duration_t                float64
# duration_m                float64
# tag_count                   int64
# dtype: object

# %% [markdown]
# ### Exploratory Data Analysis

# %%
# Create A Box Plot to sort the channels with the best performing videos (The first 5 items had such a large viewCount, I will explore them separately)

# Set Figure Size
plt.figure(figsize = (12,10))

# Set Boxplot parameters
ax = sns.boxplot(data=(video_df).sort_values('viewCount',ascending = False )[1:100],x = 'channelTitle', y = 'viewCount', palette = 'nipy_spectral')
ax.set_title('Channels with the Best Performing Videos', size = 16) 
ax.set_ylabel('Views (Number of Clicks in Millions)', size = 14)
ax.set_xlabel('Channels', size = 14)
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos:'{:,.3g}'.format(x/1000000)))
plot = ax.set_xticklabels(ax.get_xticklabels())
#sns.swarmplot(data=(video_df).sort_values('viewCount',ascending = False )[6:100],x = 'channelTitle', y = 'viewCount', palette = 'nipy_spectral')
#plt.show()
# Out:
# Text(0.5, 1.0, 'Channels with the Best Performing Videos')
# Text(0, 0.5, 'Views (Number of Clicks in Millions)')
# Text(0.5, 0, 'Channels')

# %%
# Create A Box Plot to sort the channels with the best performing videos (The first 5 items had such a large viewCount, I will explore them separately)
plt.figure(figsize = (12,10))  
sns.set(style = 'white')
ax = sns.barplot(data=(video_df).sort_values('viewCount',ascending = False )[0:5],y = 'title', x = 'viewCount',palette = 'nipy_spectral')
ax.set_title('Top 5 Performing Videos', size = 16) # Excluded top 5 videos, will add them to cu
ax.set_xlabel('Views (Number of Clicks in Millions)', size = 14)
ax.set_ylabel('', size = 14)
plot = ax.set_xticklabels(ax.get_xticklabels())
ax.xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos:'{:,.3g}'.format(x/1000000)))
# Out:
# Text(0.5, 1.0, 'Top 5 Performing Videos')
# Text(0.5, 0, 'Views (Number of Clicks in Millions)')
# Text(0, 0.5, '')

# %% [markdown]
# ## Keyword Frequency
# <font size = 3> I wanted a way to visualize Keyword Frequency in Titles so I created a Word Cloud </font>

# %%
# Create a mask
mask = np.array(Image.open('mask-upvote.png'))
          
# Create stopword list:    
stop_words = set(stopwords.words('english'))
video_df['title_no_stopwords'] = video_df['title'].apply(lambda x: [item for item in str(x).split() if item not in stop_words])
all_words = list([a for b in video_df['title_no_stopwords'].tolist() for a in b])
all_words_str = ' '.join(all_words) 

# Generate a word cloud image
def plot_cloud(wordcloud):
    plt.figure(figsize=(14, 12))
    plt.imshow(wordcloud) 
    plt.axis("off");

wordcloud = WordCloud(width = 2000, height = 2000, random_state=1, background_color= 'black', 
                      colormap='Blues', collocations=False,mask = mask).generate(all_words_str)
# Display word cloud image
plot_cloud(wordcloud)

# Save word cloud image to file in current directory
cloud =  wordcloud.to_file('wordcloud.png')

# %%
import isodate

"""
Exploring Data from Best Performing Videos based on ViewCount 
video_df_G # Chloe Ting
video_df_J # Pamela Reif
video_df_B # Emi Wong
video_df_C # Lilly Sabri
"""

# Convert Duration to seconds
video_df_G['durationSecs'] = video_df_G['duration'].apply(lambda x : isodate.parse_duration(x))
video_df_C['durationSecs'] = video_df_C['duration'].apply(lambda x : isodate.parse_duration(x))
video_df_J['durationSecs'] = video_df_J['duration'].apply(lambda x : isodate.parse_duration(x))
video_df_B['durationSecs'] = video_df_B['duration'].apply(lambda x : isodate.parse_duration(x))

video_df_G['duration_t'] = video_df_G['durationSecs'].astype('timedelta64[s]')
video_df_J['duration_t'] = video_df_J['durationSecs'].astype('timedelta64[s]')
video_df_B['duration_t'] = video_df_B['durationSecs'].astype('timedelta64[s]')
video_df_C['duration_t'] = video_df_C['durationSecs'].astype('timedelta64[s]')


#Set Columns to Numerical Datatypes
numeric_cols =['viewCount', 'likeCount', 'favouriteCount', 'duration_t']

video_df_G[numeric_cols] = video_df_G[numeric_cols].apply(pd.to_numeric,errors = 'coerce', axis = 1)
video_df_J[numeric_cols] = video_df_J[numeric_cols].apply(pd.to_numeric,errors = 'coerce', axis = 1)
video_df_B[numeric_cols] = video_df_B[numeric_cols].apply(pd.to_numeric,errors = 'coerce', axis =1)
video_df_C[numeric_cols] = video_df_C[numeric_cols].apply(pd.to_numeric,errors = 'coerce', axis =1)


#Truncate Video Titles
video_df_G['new_title'] = video_df_G['title'].str[:36]
video_df_J['new_title'] = video_df_J['title'].str[:36]
video_df_B['new_title'] = video_df_B['title'].str[:30]
video_df_C['new_title'] = video_df_C['title'].str[:36]


# When Using combined top videos use the following format
top_videos_df = pd.concat([video_df_G, video_df_J,video_df_B,video_df_C], axis = 0)
# Out:
# '\nExploring Data from Best Performing Videos based on ViewCount \nvideo_df_G # Chloe Ting\nvideo_df_J # Pamela Reif\nvideo_df_B # Emi Wong\nvideo_df_C # Lilly Sabri\n'

# %%
top_videos_df
# Out:
#         video_id channelTitle  \
# 0    85ici-FoXcY   Chloe Ting
# 1    DCNfkVg3dps   Chloe Ting
# 2    WzYbPPnvIto   Chloe Ting
# 3    FjeuJpjSgKA   Chloe Ting
# 4    l_PpoVPfTzI   Chloe Ting
# ..           ...          ...
# 791  MWnGfqJDwd0  Lilly Sabri
# 792  QNVFLjNrkPk  Lilly Sabri
# 793  P-69uWWGipg  Lilly Sabri
# 794  MKvJe_mWEuM  Lilly Sabri
# 795  qaJuJiS9BTw  Lilly Sabri
#
#                                                  title  \
# 0    Get ABS with this INTENSE 10 Min Ab Workout - ...
# 1    Best HIIT Workout to Lose Weight - Get Abs Cha...
# 2             How I plan my workouts.. secrets exposed
# 3               ouch.. fitness fails you need to avoid
# 4    Full Body Burn - INTENSE but do-able! - Summer...
# ..                                                 ...
# 791         10 Minute Intense Ab Workout | Lilly Sabri
# 792          Hourglass Sculpting Workout | Lilly Sabri
# 793       Get Your Dream Abs | Correct Core Activation
# 794     The Ultimate Legs & Booty Fat Burner | 10 Mins
# 795                                Be:Fit London 2017!
#
#                                            description  \
# 0    Time to work your abs! Brand new 10 min abs ro...
# 1    This is episode 1 of the 18 day Get Abs Challe...
# 2    Secrets out. This is how I plann my workouts. ...
# 3    Be safe while working out! Do drop me a like a...
# 4    20 Mins Full Body Burn! Low impacts included s...
# ..                                                 ...
# 791
# 792  PART 1\nThis is the perfect workout for all my...
# 793  I HAVE A QUESTION FOR YOU\nWho is struggling t...
# 794  The truth is in the name, this really is THE U...
# 795  This year I was lucky enough to host at the UK...
#
#                                                   tags           publishedAt  \
# 0    [abs, ab, core, 10 min abs, home workout, home...  2022-07-11T13:00:07Z
# 1    [hiit, workout, 15 min workout, home workout, ...  2022-07-06T13:00:07Z
# 2    [chloeting, chloe ting, chloetingchallenge, fi...  2022-06-21T14:00:22Z
# 3    [chloeting, chloe ting, chloetingchallenge, fi...  2022-06-07T13:00:07Z
# 4    [hiit workout, hiit, full body workout, weight...  2022-06-01T13:00:18Z
# ..                                                 ...                   ...
# 791  [fitness, ab, workout, walk through, lilly sab...  2017-08-09T19:51:25Z
# 792  [lilly sabri, workout, abs, glutes, bum, belly...  2017-08-02T18:31:40Z
# 793  [Abs, fitness, wellbeing, fitness & wellbeing,...  2017-07-19T21:31:10Z
# 794  [Spain, Fitness, wellbeing, HIIT, fitness and ...  2017-07-19T21:30:54Z
# 795  [Womens fitness, fitness, health, befit london...  2017-07-19T21:18:37Z
#
#      viewCount  likeCount  favouriteCount commentCount  duration definition  \
# 0      47386.0     4835.0             NaN          375  PT11M10S         hd
# 1     280286.0    13512.0             NaN          538  PT16M17S         hd
# 2     206236.0     6296.0             NaN          584  PT11M11S         hd
# 3     190713.0     6413.0             NaN          509   PT8M23S         hd
# 4     962529.0    31965.0             NaN          743  PT20M57S         hd
# ..         ...        ...             ...          ...       ...        ...
# 791    51255.0     1035.0             NaN           11  PT15M55S         hd
# 792   171859.0     3995.0             NaN           96  PT19M22S         hd
# 793    81760.0     2309.0             NaN           60   PT8M16S         hd
# 794    40213.0     1080.0             NaN           28  PT12M31S         hd
# 795    18563.0      540.0             NaN           32     PT33S         hd
#
#     caption    durationSecs  duration_t                             new_title
# 0     false 0 days 00:11:10       670.0  Get ABS with this INTENSE 10 Min Ab
# 1     false 0 days 00:16:17       977.0  Best HIIT Workout to Lose Weight - G
# 2     false 0 days 00:11:11       671.0  How I plan my workouts.. secrets exp
# 3     false 0 days 00:08:23       503.0  ouch.. fitness fails you need to avo
# 4     false 0 days 00:20:57      1257.0  Full Body Burn - INTENSE but do-able
# ..      ...             ...         ...                                   ...
# 791   false 0 days 00:15:55       955.0  10 Minute Intense Ab Workout | Lilly
# 792   false 0 days 00:19:22      1162.0  Hourglass Sculpting Workout | Lilly
# 793   false 0 days 00:08:16       496.0  Get Your Dream Abs | Correct Core Ac
# 794   false 0 days 00:12:31       751.0  The Ultimate Legs & Booty Fat Burner
# 795   false 0 days 00:00:33        33.0                   Be:Fit London 2017!
#
# [1747 rows x 16 columns]

# %% [raw]
# top_videos_df.index.duplicated()

# %%
video_df_G #Chloe Ting
# Out:
#         video_id channelTitle  \
# 0    85ici-FoXcY   Chloe Ting
# 1    DCNfkVg3dps   Chloe Ting
# 2    WzYbPPnvIto   Chloe Ting
# 3    FjeuJpjSgKA   Chloe Ting
# 4    l_PpoVPfTzI   Chloe Ting
# ..           ...          ...
# 360  BnYrdALiG2I   Chloe Ting
# 361  7VDR4kF1FGk   Chloe Ting
# 362  3HXmmUGz-Bo   Chloe Ting
# 363  -IfUFvvfWEs   Chloe Ting
# 364  _k8JXQ9NVwU   Chloe Ting
#
#                                                  title  \
# 0    Get ABS with this INTENSE 10 Min Ab Workout - ...
# 1    Best HIIT Workout to Lose Weight - Get Abs Cha...
# 2             How I plan my workouts.. secrets exposed
# 3               ouch.. fitness fails you need to avoid
# 4    Full Body Burn - INTENSE but do-able! - Summer...
# ..                                                 ...
# 360               Festival Lookbook | Festival Outfits
# 361      Spring Outfits 2016 | Another Spring Lookbook
# 362       Healthy Sweet Snacks | 9 Healthy Snack Ideas
# 363              Spring Lookbook 2016 | Spring Outfits
# 364            10 Fashion Hacks | Cleaning White Shoes
#
#                                            description  \
# 0    Time to work your abs! Brand new 10 min abs ro...
# 1    This is episode 1 of the 18 day Get Abs Challe...
# 2    Secrets out. This is how I plann my workouts. ...
# 3    Be safe while working out! Do drop me a like a...
# 4    20 Mins Full Body Burn! Low impacts included s...
# ..                                                 ...
# 360  | Music Festival Lookbook 2016  | Outfit Ideas...
# 361  Spring Lookbook 2016 | Spring Outfits 2016 | S...
# 362  Healthy sweet treats | Healthy Recipes | Low C...
# 363  Spring Lookbook 2016 | Spring Outfits | Spring...
# 364  10 fashion life hacks | fashion hacks you need...
#
#                                                   tags           publishedAt  \
# 0    [abs, ab, core, 10 min abs, home workout, home...  2022-07-11T13:00:07Z
# 1    [hiit, workout, 15 min workout, home workout, ...  2022-07-06T13:00:07Z
# 2    [chloeting, chloe ting, chloetingchallenge, fi...  2022-06-21T14:00:22Z
# 3    [chloeting, chloe ting, chloetingchallenge, fi...  2022-06-07T13:00:07Z
# 4    [hiit workout, hiit, full body workout, weight...  2022-06-01T13:00:18Z
# ..                                                 ...                   ...
# 360  [Festival Lookbook, Coachella Lookbook, Music ...  2016-04-21T13:20:46Z
# 361  [Spring outfits, Spring, Spring outfit ideas, ...  2016-04-07T13:38:23Z
# 362  [Healthy, snacks, ideas, healthy desserts, hea...  2016-03-25T13:00:05Z
# 363  [Spring lookbook 2016, 2016, spring, lookbook,...  2016-03-17T12:49:24Z
# 364  [cleaning white shoes, fashion hacks, cleaning...  2016-03-03T13:06:00Z
#
#      viewCount  likeCount  favouriteCount commentCount  duration definition  \
# 0      47386.0     4835.0             NaN          375  PT11M10S         hd
# 1     280286.0    13512.0             NaN          538  PT16M17S         hd
# 2     206236.0     6296.0             NaN          584  PT11M11S         hd
# 3     190713.0     6413.0             NaN          509   PT8M23S         hd
# 4     962529.0    31965.0             NaN          743  PT20M57S         hd
# ..         ...        ...             ...          ...       ...        ...
# 360    86511.0     2841.0             NaN          212   PT3M33S         hd
# 361    67816.0     2035.0             NaN          165   PT2M54S         hd
# 362   261288.0     8353.0             NaN          248      PT8M         hd
# 363   253963.0     5349.0             NaN          294   PT3M23S         hd
# 364   201712.0     4755.0             NaN          247   PT2M35S         hd
#
#     caption    durationSecs  duration_t                             new_title
# 0     false 0 days 00:11:10       670.0  Get ABS with this INTENSE 10 Min Ab
# 1     false 0 days 00:16:17       977.0  Best HIIT Workout to Lose Weight - G
# 2     false 0 days 00:11:11       671.0  How I plan my workouts.. secrets exp
# 3     false 0 days 00:08:23       503.0  ouch.. fitness fails you need to avo
# 4     false 0 days 00:20:57      1257.0  Full Body Burn - INTENSE but do-able
# ..      ...             ...         ...                                   ...
# 360   false 0 days 00:03:33       213.0  Festival Lookbook | Festival Outfits
# 361   false 0 days 00:02:54       174.0  Spring Outfits 2016 | Another Spring
# 362   false 0 days 00:08:00       480.0  Healthy Sweet Snacks | 9 Healthy Sna
# 363   false 0 days 00:03:23       203.0  Spring Lookbook 2016 | Spring Outfit
# 364   false 0 days 00:02:35       155.0  10 Fashion Hacks | Cleaning White Sh
#
# [365 rows x 16 columns]

# %%
video_df_G['var_ViewCount'] = video_df_G['viewCount']/max(video_df_G['viewCount'])
video_df_G
# Out:
#         video_id channelTitle  \
# 0    85ici-FoXcY   Chloe Ting
# 1    DCNfkVg3dps   Chloe Ting
# 2    WzYbPPnvIto   Chloe Ting
# 3    FjeuJpjSgKA   Chloe Ting
# 4    l_PpoVPfTzI   Chloe Ting
# ..           ...          ...
# 360  BnYrdALiG2I   Chloe Ting
# 361  7VDR4kF1FGk   Chloe Ting
# 362  3HXmmUGz-Bo   Chloe Ting
# 363  -IfUFvvfWEs   Chloe Ting
# 364  _k8JXQ9NVwU   Chloe Ting
#
#                                                  title  \
# 0    Get ABS with this INTENSE 10 Min Ab Workout - ...
# 1    Best HIIT Workout to Lose Weight - Get Abs Cha...
# 2             How I plan my workouts.. secrets exposed
# 3               ouch.. fitness fails you need to avoid
# 4    Full Body Burn - INTENSE but do-able! - Summer...
# ..                                                 ...
# 360               Festival Lookbook | Festival Outfits
# 361      Spring Outfits 2016 | Another Spring Lookbook
# 362       Healthy Sweet Snacks | 9 Healthy Snack Ideas
# 363              Spring Lookbook 2016 | Spring Outfits
# 364            10 Fashion Hacks | Cleaning White Shoes
#
#                                            description  \
# 0    Time to work your abs! Brand new 10 min abs ro...
# 1    This is episode 1 of the 18 day Get Abs Challe...
# 2    Secrets out. This is how I plann my workouts. ...
# 3    Be safe while working out! Do drop me a like a...
# 4    20 Mins Full Body Burn! Low impacts included s...
# ..                                                 ...
# 360  | Music Festival Lookbook 2016  | Outfit Ideas...
# 361  Spring Lookbook 2016 | Spring Outfits 2016 | S...
# 362  Healthy sweet treats | Healthy Recipes | Low C...
# 363  Spring Lookbook 2016 | Spring Outfits | Spring...
# 364  10 fashion life hacks | fashion hacks you need...
#
#                                                   tags           publishedAt  \
# 0    [abs, ab, core, 10 min abs, home workout, home...  2022-07-11T13:00:07Z
# 1    [hiit, workout, 15 min workout, home workout, ...  2022-07-06T13:00:07Z
# 2    [chloeting, chloe ting, chloetingchallenge, fi...  2022-06-21T14:00:22Z
# 3    [chloeting, chloe ting, chloetingchallenge, fi...  2022-06-07T13:00:07Z
# 4    [hiit workout, hiit, full body workout, weight...  2022-06-01T13:00:18Z
# ..                                                 ...                   ...
# 360  [Festival Lookbook, Coachella Lookbook, Music ...  2016-04-21T13:20:46Z
# 361  [Spring outfits, Spring, Spring outfit ideas, ...  2016-04-07T13:38:23Z
# 362  [Healthy, snacks, ideas, healthy desserts, hea...  2016-03-25T13:00:05Z
# 363  [Spring lookbook 2016, 2016, spring, lookbook,...  2016-03-17T12:49:24Z
# 364  [cleaning white shoes, fashion hacks, cleaning...  2016-03-03T13:06:00Z
#
#      viewCount  likeCount  favouriteCount commentCount  duration definition  \
# 0      47386.0     4835.0             NaN          375  PT11M10S         hd
# 1     280286.0    13512.0             NaN          538  PT16M17S         hd
# 2     206236.0     6296.0             NaN          584  PT11M11S         hd
# 3     190713.0     6413.0             NaN          509   PT8M23S         hd
# 4     962529.0    31965.0             NaN          743  PT20M57S         hd
# ..         ...        ...             ...          ...       ...        ...
# 360    86511.0     2841.0             NaN          212   PT3M33S         hd
# 361    67816.0     2035.0             NaN          165   PT2M54S         hd
# 362   261288.0     8353.0             NaN          248      PT8M         hd
# 363   253963.0     5349.0             NaN          294   PT3M23S         hd
# 364   201712.0     4755.0             NaN          247   PT2M35S         hd
#
#     caption    durationSecs  duration_t                             new_title  \
# 0     false 0 days 00:11:10       670.0  Get ABS with this INTENSE 10 Min Ab
# 1     false 0 days 00:16:17       977.0  Best HIIT Workout to Lose Weight - G
# 2     false 0 days 00:11:11       671.0  How I plan my workouts.. secrets exp
# 3     false 0 days 00:08:23       503.0  ouch.. fitness fails you need to avo
# 4     false 0 days 00:20:57      1257.0  Full Body Burn - INTENSE but do-able
# ..      ...             ...         ...                                   ...
# 360   false 0 days 00:03:33       213.0  Festival Lookbook | Festival Outfits
# 361   false 0 days 00:02:54       174.0  Spring Outfits 2016 | Another Spring
# 362   false 0 days 00:08:00       480.0  Healthy Sweet Snacks | 9 Healthy Sna
# 363   false 0 days 00:03:23       203.0  Spring Lookbook 2016 | Spring Outfit
# 364   false 0 days 00:02:35       155.0  10 Fashion Hacks | Cleaning White Sh
#
#      var_ViewCount
# 0         0.000103
# 1         0.000609
# 2         0.000448
# 3         0.000414
# 4         0.002091
# ..             ...
# 360       0.000188
# 361       0.000147
# 362       0.000568
# 363       0.000552
# 364       0.000438
#
# [365 rows x 17 columns]

# %%
plt.figure(figsize = (12,10))
sns.set_theme(style= "white")

ax = sns.barplot(data=(video_df_G).sort_values('viewCount',ascending = False )[0:20],y = 'new_title', x = 'viewCount')
ax.set_title('Chloe Ting: Best Performing Videos', size = 18)

ax.set_ylabel(' ', size = 18)
ax.set_xlabel("View Count(millions)", size = 16)
plot = ax.set_xticklabels(ax.get_xticklabels(), rotation=0, size = 16)
ax.xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos:'{:,.3g}'.format(x/1000000)))
# Out:
# Text(0.5, 1.0, 'Chloe Ting: Best Performing Videos')
# Text(0, 0.5, ' ')
# Text(0.5, 0, 'View Count(millions)')

# %%
video_df_J #Pamela Reif
# Out:
#         video_id channelTitle  \
# 0    3LiZGIIXyFc  Pamela Reif
# 1    Yw9BKk83Gng  Pamela Reif
# 2    FAkZLhi30Xw  Pamela Reif
# 3    5rsLU-J8aPM  Pamela Reif
# 4    eH5Ng_9bsUQ  Pamela Reif
# ..           ...          ...
# 163  QN5Nu1aeYyc  Pamela Reif
# 164  RqfkrZA_ie0  Pamela Reif
# 165  Q-vuR4PJh2c  Pamela Reif
# 166  iY4hQd24_d0  Pamela Reif
# 167  5cMYysFl4CY  Pamela Reif
#
#                                                  title  \
# 0    20 MIN BOOTY, GYM STYLE - Circuit Training wit...
# 1    10 MIN HIIT HIIT HOORAY - a not dancy (but ver...
# 2    12 MIN BOSS BITCH WORKOUT - shake your booty &...
# 3    8 MIN HEAD TO TOE STRETCH - after your workout...
# 4    10 MIN ELEVATOR BOYS WORKOUT - Fun Full Body /...
# ..                                                 ...
# 163  SEXY ARMS IN 10 MIN  / No Equipment | Pamela Reif
# 164    10 MIN BOOTY BURN // No Equipment | Pamela Reif
# 165  10 MIN SIXPACK WORKOUT // No Equipment | Pamel...
# 166   5MIN BOOTY & AB WORKOUT // Yoga Ball | Pamela RF
# 167  10 MIN INTENSE AB WORKOUT // No Equipment | Pa...
#
#                                            description  \
# 0    You can do this at home or in the gym ♥︎ This ...
# 1    Let me trick you - HIIT / Cardio is easy today...
# 2    Omg, this is so much fun :D Even if you think ...
# 3    a perfect routine for every day ♥︎ Want to cal...
# 4    5 pretty boys to make our workout life more fu...
# ..                                                 ...
# 163  This is an INTERMEDIATE workout with options f...
# 164  A quick & intense workout to target your butt....
# 165  NO EXCUSES ♥︎  a quick & intense workout to ta...
# 166  INTENSE BOOTY & AB EXERCISES //  QUICK & EFFEC...
# 167  QUICK & INTENSE.  NO EQUIPMENT NEEDED. NO EXCU...
#
#                                                   tags           publishedAt  \
# 0    [workout, training, butt, glute, booty, ass, l...  2022-07-05T01:30:00Z
# 1    [workout, training, abs, sickpack, tummy, stom...  2022-06-29T01:30:13Z
# 2    [workout, training, abs, sickpack, flat, tummy...  2022-06-18T01:30:02Z
# 3    [workout, training, abs, sickpack, flat, tummy...  2022-06-11T01:30:01Z
# 4    [workout, training, abs, sickpack, flat, tummy...  2022-06-01T01:30:06Z
# ..                                                 ...                   ...
# 163  [workout, training, arm, core, chest, back, up...  2018-03-15T15:08:41Z
# 164  [workout, training, butt, glute, booty, ass, l...  2018-01-30T15:12:13Z
# 165  [workout, training, abs, sickpack, flat, tummy...  2018-01-08T18:38:38Z
# 166  in, 5 minutes, workout, training, abs, ab w...  2016-07-21T20:21:57Z
# 167  [Workout, ab, home, fitness, sixpack, home wor...  2016-04-21T16:55:21Z
#
#       viewCount  likeCount  favouriteCount commentCount  duration definition  \
# 0      336085.0     8698.0             NaN          285   PT20M1S         hd
# 1      537247.0    11980.0             NaN          326  PT10M47S         hd
# 2     1129825.0    28190.0             NaN         1128  PT11M50S         hd
# 3      485765.0    10714.0             NaN          247   PT9M12S         hd
# 4      877989.0    19195.0             NaN          437  PT13M45S         hd
# ..          ...        ...             ...          ...       ...        ...
# 163  10392350.0   122927.0             NaN         1737  PT10M11S         hd
# 164  49544242.0   806265.0             NaN        16061  PT11M14S         hd
# 165  54115490.0   586081.0             NaN        12655  PT10M22S         hd
# 166   5257486.0    97809.0             NaN         1066   PT5M36S         hd
# 167  15537186.0   225320.0             NaN         4318   PT9M54S         hd
#
#     caption    durationSecs  duration_t                             new_title
# 0     false 0 days 00:20:01      1201.0  20 MIN BOOTY, GYM STYLE - Circuit Tr
# 1     false 0 days 00:10:47       647.0  10 MIN HIIT HIIT HOORAY - a not danc
# 2     false 0 days 00:11:50       710.0  12 MIN BOSS BITCH WORKOUT - shake yo
# 3     false 0 days 00:09:12       552.0  8 MIN HEAD TO TOE STRETCH - after yo
# 4     false 0 days 00:13:45       825.0  10 MIN ELEVATOR BOYS WORKOUT - Fun F
# ..      ...             ...         ...                                   ...
# 163   false 0 days 00:10:11       611.0  SEXY ARMS IN 10 MIN  / No Equipment
# 164   false 0 days 00:11:14       674.0  10 MIN BOOTY BURN // No Equipment |
# 165   false 0 days 00:10:22       622.0  10 MIN SIXPACK WORKOUT // No Equipme
# 166   false 0 days 00:05:36       336.0  5MIN BOOTY & AB WORKOUT // Yoga Ball
# 167   false 0 days 00:09:54       594.0  10 MIN INTENSE AB WORKOUT // No Equi
#
# [168 rows x 16 columns]

# %%
plt.figure(figsize = (12,10))
ax = sns.barplot(data=(video_df_J).sort_values('viewCount',ascending = False )[0:20],y = 'new_title', x = 'viewCount')
ax.set_title('Pamela Reif : Best Performing Videos', size =16)
ax.set_xlabel('View Count (millions)', size = 16)
ax.set_ylabel(' ')

plot = ax.set_xticklabels(ax.get_xticklabels())
ax.xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos:'{:,.3g}'.format(x/1000000)))
# Out:
# Text(0.5, 1.0, 'Pamela Reif : Best Performing Videos')
# Text(0.5, 0, 'View Count (millions)')
# Text(0, 0.5, ' ')

# %%
video_df_B #Emi Wong
# Out:
#         video_id channelTitle  \
# 0    sc0w6wycHUI     emi wong
# 1    Evy6pj-n1eg     emi wong
# 2    -hyyVOBzjgI     emi wong
# 3    E0_mEcDReeE     emi wong
# 4    HTxclHpjG3k     emi wong
# ..           ...          ...
# 413  WwqYFnBGjT8     emi wong
# 414  DZ6voLaG9_I     emi wong
# 415  Fo470c993yA     emi wong
# 416  p1DJhMy0yCs     emi wong
# 417  zuXFRfbTmiU     emi wong
#
#                                                  title  \
# 0    [SINGAPORE VLOG] First Trip Leaving Hong Kong ...
# 1    15 min Standing Fat Burn HIIT for Weight Loss ...
# 2    20 min Abs & Legs Standing Workout | 2 Weeks S...
# 3    Flat Belly & Slim Thighs in 2 Weeks  | 30 min ...
# 4    DO CARBS MAKE YOU FAT?  Can You Eat Carbs to L...
# ..                                                 ...
# 413  Healthy Greek Yogurt Pancakes Recipe for Break...
# 414  10 min Full Body HIIT Workout - FAT BURNING No...
# 415  MY DIET - What I Eat In A Day to Stay Fit and ...
# 416  10 min Intense Ab Workout: No Equipment At Hom...
# 417  My 24 Weeks Weight Loss Journey & Eating Disor...
#
#                                            description  \
# 0    This video is in collaboration with HotelsComb...
# 1    SUBSCRIBE & TURN ON NOTIFICATIONS FOR NEW VIDE...
# 2    2022 2-Week Flat Belly & Slim Legs Challenge \...
# 3    2022 2-Week Flat Belly & Slim Legs Challenge \...
# 4    SUBSCRIBE & TURN ON NOTIFICATIONS FOR NEW VIDE...
# ..                                                 ...
# 413  ♡CHECK OUT\nHealthy Vegan Smoothies for Weight...
# 414  ♡SUBSCRIBE & TURN ON NOTIFICATIONS FOR NEW VID...
# 415  ♡SUBSCRIBE FOR WEEKLY VIDEOS  ► http://bit.ly/...
# 416  ♡SUBSCRIBE FOR WEEKLY VIDEOS  ► http://bit.ly/...
# 417  ♡SUBSCRIBE FOR WEEKLY VIDEOS  ► http://bit.ly/...
#
#                                                   tags           publishedAt  \
# 0    [singapore vlog, covid travel, leaving hong ko...  2022-07-03T12:18:34Z
# 1    [standing workout, standing hiit, full body hi...  2022-06-09T13:00:07Z
# 2    [abs and legs workout, standing abs workout, s...  2022-05-01T11:18:29Z
# 3    [abs & legs workout, abs workout, legs workout...  2022-04-24T12:31:54Z
# 4    [eat carbs, do carbs make you fat, carbohydrat...  2022-04-20T12:41:39Z
# ..                                                 ...                   ...
# 413  [healthy diet, healthy food, nutrition, health...  2017-05-10T12:54:28Z
# 414  [workout, workout video, Fitness, Full body wo...  2017-05-03T12:34:17Z
# 415  [Diet, Weight Loss, Healthy Diet, Healthy Life...  2017-04-26T13:28:55Z
# 416  [workout video, ab workout, ab exercises, ab r...  2017-04-19T14:19:49Z
# 417  [BBG, Bikini Body Guide, Kayla Itsines, Fitnes...  2017-04-12T12:50:38Z
#
#      viewCount  likeCount  favouriteCount commentCount  duration definition  \
# 0      72843.0     1544.0             NaN           88  PT14M34S         hd
# 1     235242.0     7563.0             NaN          172  PT14M56S         hd
# 2     492518.0    14075.0             NaN          229   PT21M5S         hd
# 3     633241.0    20192.0             NaN          385  PT29M51S         hd
# 4     163385.0     4175.0             NaN          111    PT4M7S         hd
# ..         ...        ...             ...          ...       ...        ...
# 413    73876.0     1612.0             NaN           73   PT7M16S         hd
# 414  9566493.0   231014.0             NaN         4733     PT13M         hd
# 415   151950.0     2256.0             NaN          116   PT15M6S         hd
# 416  2376669.0    42778.0             NaN         1290  PT13M55S         hd
# 417   948850.0    16278.0             NaN          469   PT14M4S         hd
#
#     caption    durationSecs  duration_t                       new_title
# 0     false 0 days 00:14:34       874.0  [SINGAPORE VLOG] First Trip Le
# 1     false 0 days 00:14:56       896.0  15 min Standing Fat Burn HIIT
# 2     false 0 days 00:21:05      1265.0  20 min Abs & Legs Standing Wor
# 3     false 0 days 00:29:51      1791.0  Flat Belly & Slim Thighs in 2
# 4     false 0 days 00:04:07       247.0  DO CARBS MAKE YOU FAT?  Can Yo
# ..      ...             ...         ...                             ...
# 413    true 0 days 00:07:16       436.0  Healthy Greek Yogurt Pancakes
# 414    true 0 days 00:13:00       780.0  10 min Full Body HIIT Workout
# 415   false 0 days 00:15:06       906.0  MY DIET - What I Eat In A Day
# 416    true 0 days 00:13:55       835.0  10 min Intense Ab Workout: No
# 417    true 0 days 00:14:04       844.0  My 24 Weeks Weight Loss Journe
#
# [418 rows x 16 columns]

# %%
plt.figure(figsize = (14,12))

ax = sns.barplot(data=(video_df_B).sort_values('viewCount',ascending = False )[0:20],y = 'new_title', x = 'viewCount')
ax.set_title('Emi Wong: Best Performing Videos ', size = 18)

ax.set_ylabel(' ', size = 16)
ax.set_xlabel("View Count (million)", size = 16)
plot = ax.set_xticklabels(ax.get_xticklabels())
ax.xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos:'{:,.3g}'.format(x/1000000)))
# Out:
# Text(0.5, 1.0, 'Emi Wong: Best Performing Videos ')
# Text(0, 0.5, ' ')
# Text(0.5, 0, 'View Count (million)')

# %%
video_df_C #Lilly Sabri
# Out:
#         video_id channelTitle  \
# 0    CX9HU67prfQ  Lilly Sabri
# 1    UJRqLtctfYQ  Lilly Sabri
# 2    oE7QiTnot54  Lilly Sabri
# 3    aTFGFTB6mIc  Lilly Sabri
# 4    mBSrrTjl7t4  Lilly Sabri
# ..           ...          ...
# 791  MWnGfqJDwd0  Lilly Sabri
# 792  QNVFLjNrkPk  Lilly Sabri
# 793  P-69uWWGipg  Lilly Sabri
# 794  MKvJe_mWEuM  Lilly Sabri
# 795  qaJuJiS9BTw  Lilly Sabri
#
#                                                  title  \
# 0    THIS TAKES YOUR WORKOUT TO A WHOLE NEW LEVEL 🤯...
# 1    Agree or disagree? Smoothies bowls are overrat...
# 2    I had NO choice, but to design my own Mats. He...
# 3    TOP 10 SMALLER WAIST EXERCISES (10 day results...
# 4    Summer Gymfits Must Haves! OMG you need these ...
# ..                                                 ...
# 791         10 Minute Intense Ab Workout | Lilly Sabri
# 792          Hourglass Sculpting Workout | Lilly Sabri
# 793       Get Your Dream Abs | Correct Core Activation
# 794     The Ultimate Legs & Booty Fat Burner | 10 Mins
# 795                                Be:Fit London 2017!
#
#                                            description  \
# 0    What happens before taking Pre-workout VS afte...
# 1    The most simple, yet delicious recipe from the...
# 2    Over the last 10 years of teaching classes, I’...
# 3    These are the top 10 smaller waist exercises t...
# 4    1️⃣ - 5️⃣ Which one is your fav? I'm absolutel...
# ..                                                 ...
# 791
# 792  PART 1\nThis is the perfect workout for all my...
# 793  I HAVE A QUESTION FOR YOU\nWho is struggling t...
# 794  The truth is in the name, this really is THE U...
# 795  This year I was lucky enough to host at the UK...
#
#                                                   tags           publishedAt  \
# 0    [home workout, home exercise, workout program,...  2022-07-08T15:00:13Z
# 1    [eat to get results, protein food, protein sna...  2022-07-07T15:00:18Z
# 2    [home workout, home exercise, workout program,...  2022-07-05T15:00:29Z
# 3    [home workout, home exercise, from home workou...  2022-06-30T15:00:01Z
# 4    [home workout, home exercise, workout program,...  2022-06-29T15:00:28Z
# ..                                                 ...                   ...
# 791  [fitness, ab, workout, walk through, lilly sab...  2017-08-09T19:51:25Z
# 792  [lilly sabri, workout, abs, glutes, bum, belly...  2017-08-02T18:31:40Z
# 793  [Abs, fitness, wellbeing, fitness & wellbeing,...  2017-07-19T21:31:10Z
# 794  [Spain, Fitness, wellbeing, HIIT, fitness and ...  2017-07-19T21:30:54Z
# 795  [Womens fitness, fitness, health, befit london...  2017-07-19T21:18:37Z
#
#      viewCount  likeCount  favouriteCount commentCount  duration definition  \
# 0      33988.0     1210.0             NaN           25      PT6S         hd
# 1      45943.0     1940.0             NaN           33      PT5S         hd
# 2      75984.0     3942.0             NaN           60     PT36S         hd
# 3     202689.0    10280.0             NaN          181   PT6M57S         hd
# 4      48777.0     1567.0             NaN           22      PT2S         hd
# ..         ...        ...             ...          ...       ...        ...
# 791    51255.0     1035.0             NaN           11  PT15M55S         hd
# 792   171859.0     3995.0             NaN           96  PT19M22S         hd
# 793    81760.0     2309.0             NaN           60   PT8M16S         hd
# 794    40213.0     1080.0             NaN           28  PT12M31S         hd
# 795    18563.0      540.0             NaN           32     PT33S         hd
#
#     caption    durationSecs  duration_t                             new_title
# 0     false 0 days 00:00:06         6.0  THIS TAKES YOUR WORKOUT TO A WHOLE N
# 1     false 0 days 00:00:05         5.0  Agree or disagree? Smoothies bowls a
# 2     false 0 days 00:00:36        36.0  I had NO choice, but to design my ow
# 3      true 0 days 00:06:57       417.0  TOP 10 SMALLER WAIST EXERCISES (10 d
# 4     false 0 days 00:00:02         2.0  Summer Gymfits Must Haves! OMG you n
# ..      ...             ...         ...                                   ...
# 791   false 0 days 00:15:55       955.0  10 Minute Intense Ab Workout | Lilly
# 792   false 0 days 00:19:22      1162.0  Hourglass Sculpting Workout | Lilly
# 793   false 0 days 00:08:16       496.0  Get Your Dream Abs | Correct Core Ac
# 794   false 0 days 00:12:31       751.0  The Ultimate Legs & Booty Fat Burner
# 795   false 0 days 00:00:33        33.0                   Be:Fit London 2017!
#
# [796 rows x 16 columns]

# %%
plt.figure(figsize = (12,10))

ax = sns.barplot(data=(video_df_C).sort_values('viewCount',ascending = False )[0:20],y = 'new_title', x = 'viewCount')
ax.set_title('Lilly Sabri: Best Performing Videos ', size = 16)

ax.set_ylabel(' ')
ax.set_xlabel("View Count (million)", size = 14)
plot = ax.set_xticklabels(ax.get_xticklabels())
ax.xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos:'{:,.3g}'.format(x/1000000)))
# Out:
# Text(0.5, 1.0, 'Lilly Sabri: Best Performing Videos ')
# Text(0, 0.5, ' ')
# Text(0.5, 0, 'View Count (million)')

# %% [raw]
# median_G = video_df_G["duration_t"].median()%60
# median_G

# %%
'''
video_df_G # Chloe Ting
video_df_J # Pamela Reif
video_df_B # Emi Wong
video_df_C # Lilly Sabri

'''

sns.set_theme(style="whitegrid")
plt.figure(figsize = (25,25))
sns.set(font_scale=1.2) 
plt.tick_params(axis='both', which='major', labelsize=14)
plt.subplot(2,2,2)
ax = sns.scatterplot(data=(video_df_G).sort_values('duration_t',ascending = True)  ,x = 'duration_t', y = 'viewCount')
ax.set_title('Chloe Ting: Views as a function of Duration', size = 18)
ax.set_xlabel("Duration (minutes)" , size = 16 )
ax.set_ylabel("View Count (million)", size = 16)
plot = ax.set_xticklabels(ax.get_xticklabels(),rotation=0,fontsize=14)
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos:'{:,.3g}'.format(x/1000000) ))
ax.xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos:'{:,.3g}'.format(round(x/60)) + 'mins'))

plt.subplot(2,2,1)
ax = sns.scatterplot(data=(video_df_J).sort_values('duration_t',ascending = True) ,x = 'duration_t', y = 'viewCount')
ax.set_title('Pamela Reif: Views as a function of Duration', size = 18)
ax.set_xlabel("Duration (minutes)" , size = 16 )
ax.set_ylabel("View Count (millions)", size = 16)
plot = ax.set_xticklabels(ax.get_xticklabels(),rotation=0,fontsize=14)
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos:'{:,.3g}'.format(x/1000000) ))
ax.xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos:'{:,.3g}'.format(round(x/60)) + 'mins'))

plt.subplot(2,2,3)
ax = sns.scatterplot(data=(video_df_B).sort_values('duration_t',ascending = True) ,x = 'duration_t', y = 'viewCount')
ax.set_title('Emi Wong: Views as a function of Duration', size = 18)
ax.set_xlabel("Duration (minutes)" , size = 16 )
ax.set_ylabel("View Count (millions)", size = 16)
plot = ax.set_xticklabels(ax.get_xticklabels(),rotation=0,fontsize=14)
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos:'{:,.3g}'.format(x/1000000) ))
ax.xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos:'{:,.3g}'.format(round(x/60)) + 'mins'))


plt.subplot(2,2,4)
#ax.set_xlim(0, 60000000)
ax = sns.scatterplot(data=(video_df_C).sort_values('duration_t',ascending = True) ,x = 'duration_t', y = 'viewCount')
ax.set_title('Lilly Sabri: Views as a function of Duration', size = 18)
ax.set_xlabel("Duration (minutes)" , size = 16 )
ax.set_ylabel("View Count (millions)", size = 16)
plot = ax.set_xticklabels(ax.get_xticklabels(),rotation=0,fontsize=14)
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos:'{:,.3g}'.format(x/1000000) ))
ax.xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos:'{:,.3g}'.format(round(x/60)) + 'mins'))
# Out:
# '\nvideo_df_G # Chloe Ting\nvideo_df_J # Pamela Reif\nvideo_df_B # Emi Wong\nvideo_df_C # Lilly Sabri\n\n'
# <AxesSubplot:>
# Text(0.5, 1.0, 'Chloe Ting: Views as a function of Duration')
# Text(0.5, 0, 'Duration (minutes)')
# Text(0, 0.5, 'View Count (million)')
# <AxesSubplot:>
# Text(0.5, 1.0, 'Pamela Reif: Views as a function of Duration')
# Text(0.5, 0, 'Duration (minutes)')
# Text(0, 0.5, 'View Count (millions)')
# <AxesSubplot:>
# Text(0.5, 1.0, 'Emi Wong: Views as a function of Duration')
# Text(0.5, 0, 'Duration (minutes)')
# Text(0, 0.5, 'View Count (millions)')
# <AxesSubplot:>
# Text(0.5, 1.0, 'Lilly Sabri: Views as a function of Duration')
# Text(0.5, 0, 'Duration (minutes)')
# Text(0, 0.5, 'View Count (millions)')

# %%
sorted_playlist_df = top_videos_df.sort_values('viewCount',ascending = False )[0:20]
sorted_playlist_df
# Out:
#         video_id channelTitle  \
# 184  2pLT-olgUJs   Chloe Ting
# 185  2MoGxae-zyo   Chloe Ting
# 150  AnYl6Nk9GOA  Pamela Reif
# 207  6TmQiugy_qw   Chloe Ting
# 165  jXm0y-csiuE     emi wong
# 143  1f8yoFFdkcY  Pamela Reif
# 132  -p0PA9Zt8zk   Chloe Ting
# 235  UBnfm4s7CRA   Chloe Ting
# 165  Q-vuR4PJh2c  Pamela Reif
# 381  ohgLmY19jNg  Lilly Sabri
# 162  UBMk30rjy0o  Pamela Reif
# 164  RqfkrZA_ie0  Pamela Reif
# 152  UItWltVZZmE  Pamela Reif
# 99   h8ctkfSx6R0   Chloe Ting
# 140  cIuiQyfKBTg   Chloe Ting
# 174  j64BBgBGNIU   Chloe Ting
# 139  LjmZ1YMOwws   Chloe Ting
# 183  I9nG-G4B5Bs   Chloe Ting
# 207  W4eKVKwf3rQ     emi wong
# 120  Cw-Wt4xKD2s  Pamela Reif
#
#                                                  title  \
# 184         Get Abs in 2 WEEKS | Abs Workout Challenge
# 185  Do This Everyday To Lose Weight | 2 Weeks Shre...
# 150    10 MIN AB WORKOUT // No Equipment | Pamela Reif
# 207       Abs Workout 🔥Get that 11 Line Abs in 35 days
# 165  10 MIN EXERCISE & STRETCH FOR SHOULDERS, NECK ...
# 143  10 MIN BEGINNER AB WORKOUT // No Equipment | P...
# 132  Do This Warm Up Before Your Workouts | Quick W...
# 235  10 Mins ABS Workout To Get FLAT BELLY IN 30 DA...
# 165  10 MIN SIXPACK WORKOUT // No Equipment | Pamel...
# 381  LOSE FAT in 7 days (belly, waist & abs) | 5 mi...
# 162  20 MIN FULL BODY WORKOUT // No Equipment | Pam...
# 164    10 MIN BOOTY BURN // No Equipment | Pamela Reif
# 152  20 MIN FULL BODY WORKOUT - Beginner Version //...
# 99         Abs in 2 Weeks | Abs Workout Challenge 2020
# 140  Tiny Waist & Round Butt Workout | At Home Hour...
# 174          10 Mins Toned Arms Workout | No Equipment
# 139  Hips Dips Workout | 10 Min Side Booty Exercise...
# 183  Lower Body Workout | Toned Legs & Butt | 2 Wee...
# 207  30 min Full Body Fat Burn HIIT (NO JUMPING) - ...
# 120  15 MIN HAPPY DANCE WORKOUT - burn calories and...
#
#                                            description  \
# 184  Abs Abs Abs! Everyone seems to be asking for a...
# 185  First episode of my new program for this month...
# 150  inspired by my most popular "Sixpack Workout" ...
# 207  Want that 11 line abs? It's the 2019 Summer Sh...
# 165  SUBSCRIBE & TURN ON NOTIFICATIONS FOR NEW VIDE...
# 143  Ohhhh yes - a BEGINNER ab workout! ♥︎ / Werbun...
# 132  It's the new 2020 Summer Shred! Here's a brand...
# 235  This is a 10 mins intense abs workout that wil...
# 165  NO EXCUSES ♥︎  a quick & intense workout to ta...
# 381  Lose belly, waist and abs fat in 7 days with t...
# 162  NO EXCUSES ♥︎  a Full Body Workout that can do...
# 164  A quick & intense workout to target your butt....
# 152  Finally: a workout suitable for BEGINNERS. // ...
# 99   ABS ABS ABS! Check out the NEW get abs in 2 we...
# 140  Back with an hourglass program, focusing on th...
# 174  This is the final episode of the Lean Arms Cha...
# 139  Time for a booty workout for hip dips as part ...
# 183  Time to work on those legs and butt of yours i...
# 207  SUBSCRIBE & TURN ON NOTIFICATIONS FOR NEW VIDE...
# 120  .. ready to DANCE (and get really, really swea...
#
#                                                   tags           publishedAt  \
# 184  [abs, abs workout, abs exercise, lower abs wor...  2019-08-12T11:45:00Z
# 185  [workout, daily workout, home workout, full bo...  2019-08-08T11:45:00Z
# 150  [workout, training, abs, sickpack, flat, tummy...  2019-10-20T07:00:00Z
# 207  [abs, abs workout, abs exercise, 11 abs, 11 ab...  2019-04-30T11:08:03Z
# 165  [collarbone workout, shoulder workout, sexy co...  2020-04-05T12:07:57Z
# 143  [workout, training, abs, sickpack, flat, tummy...  2020-02-16T08:00:00Z
# 132  [warm up, warm up exercise, warm up exercise b...  2020-05-08T12:32:53Z
# 235  [abs, abs workout, abs exercise, lower ab work...  2019-01-03T11:48:26Z
# 165  [workout, training, abs, sickpack, flat, tummy...  2018-01-08T18:38:38Z
# 381  [home workout, home exercise, workout program,...  2020-05-08T16:30:12Z
# 162  [workout, training, full body, butt, glute, bo...  2018-04-29T16:29:19Z
# 164  [workout, training, butt, glute, booty, ass, l...  2018-01-30T15:12:13Z
# 152  [workout, training, full body, butt, glute, bo...  2019-09-01T10:12:36Z
# 99   [abs, abs workout, abs exercise, lower abs wor...  2020-08-31T12:30:05Z
# 140  [tiny waist, waist, hourglass, hourglass figur...  2020-04-06T12:19:57Z
# 174  [arms workout, arms exercise, standing arms ex...  2019-10-02T11:17:08Z
# 139  [booty, booty workout, booty exercise, butt wo...  2020-04-07T12:22:39Z
# 183  [butt, butt workout, butt workout for women, b...  2019-08-14T11:45:02Z
# 207  [30 min workout, quiet workout, no jumping wor...  2019-10-09T12:44:04Z
# 120  [workout, training, abs, sickpack, flat, tummy...  2020-05-20T05:30:00Z
#
#        viewCount  likeCount  favouriteCount commentCount  duration definition  \
# 184  460268164.0  8095923.0             NaN       294284   PT11M4S         hd
# 185  194459505.0  3845890.0             NaN       146872  PT14M23S         hd
# 150   76248253.0   795778.0             NaN        19326  PT10M26S         hd
# 207   71279463.0  1478372.0             NaN        43556   PT11M8S         hd
# 165   68807210.0  1450531.0             NaN        21621  PT10M30S         hd
# 143   64215509.0   824706.0             NaN        13820  PT10M30S         hd
# 132   59055839.0   565160.0             NaN         7866   PT6M27S         hd
# 235   56114438.0  1625880.0             NaN        31227   PT11M3S         hd
# 165   54115490.0   586081.0             NaN        12655  PT10M22S         hd
# 381   53385273.0  1520407.0             NaN        49212   PT5M53S         hd
# 162   51856256.0   815280.0             NaN        19060  PT20M20S         hd
# 164   49544242.0   806265.0             NaN        16061  PT11M14S         hd
# 152   49499899.0   670101.0             NaN        19680  PT21M55S         hd
# 99    46794179.0   757145.0             NaN        24634  PT11M29S         hd
# 140   44643361.0   862318.0             NaN        25451  PT16M28S         hd
# 174   41574806.0   625020.0             NaN        14402  PT10M58S         hd
# 139   38720294.0   789076.0             NaN        18339  PT11M19S         hd
# 183   38507258.0   620138.0             NaN        17758  PT13M12S         hd
# 207   36111429.0   558410.0             NaN        12711  PT30M55S         hd
# 120   34521359.0   372710.0             NaN         7092  PT14M26S         hd
#
#     caption    durationSecs  duration_t                             new_title
# 184    true 0 days 00:11:04       664.0  Get Abs in 2 WEEKS | Abs Workout Cha
# 185    true 0 days 00:14:23       863.0  Do This Everyday To Lose Weight | 2
# 150   false 0 days 00:10:26       626.0  10 MIN AB WORKOUT // No Equipment |
# 207    true 0 days 00:11:08       668.0  Abs Workout 🔥Get that 11 Line Abs in
# 165    true 0 days 00:10:30       630.0        10 MIN EXERCISE & STRETCH FOR
# 143   false 0 days 00:10:30       630.0  10 MIN BEGINNER AB WORKOUT // No Equ
# 132    true 0 days 00:06:27       387.0  Do This Warm Up Before Your Workouts
# 235    true 0 days 00:11:03       663.0  10 Mins ABS Workout To Get FLAT BELL
# 165   false 0 days 00:10:22       622.0  10 MIN SIXPACK WORKOUT // No Equipme
# 381    true 0 days 00:05:53       353.0  LOSE FAT in 7 days (belly, waist & a
# 162   false 0 days 00:20:20      1220.0  20 MIN FULL BODY WORKOUT // No Equip
# 164   false 0 days 00:11:14       674.0  10 MIN BOOTY BURN // No Equipment |
# 152   false 0 days 00:21:55      1315.0  20 MIN FULL BODY WORKOUT - Beginner
# 99     true 0 days 00:11:29       689.0  Abs in 2 Weeks | Abs Workout Challen
# 140    true 0 days 00:16:28       988.0  Tiny Waist & Round Butt Workout | At
# 174    true 0 days 00:10:58       658.0  10 Mins Toned Arms Workout | No Equi
# 139    true 0 days 00:11:19       679.0  Hips Dips Workout | 10 Min Side Boot
# 183    true 0 days 00:13:12       792.0  Lower Body Workout | Toned Legs & Bu
# 207    true 0 days 00:30:55      1855.0        30 min Full Body Fat Burn HIIT
# 120   false 0 days 00:14:26       866.0  15 MIN HAPPY DANCE WORKOUT - burn ca

# %% [markdown]
# <iframe width="720" height="405" src="https://www.youtube.com/watch_videos?video_ids=Cw-Wt4xKD2s,W4eKVKwf3rQ,I9nG-G4B5Bs" frameborder = "0" allowfullscreen>

# %%
target_playlist_id = 'PLC1Z0cuNyOuaWqP1vXXMZkn3T2RjDGBi5'

# %%
# Create playlist
video_ids = ['2pLT-olgUJs','2MoGxae-zyo,AnYl6Nk9GOA',
             '6TmQiugy_qw,jXm0y-csiuE','1f8yoFFdkcY',
             '-p0PA9Zt8zk','UBnfm4s7CRA','Q-vuR4PJh2c',
             'ohgLmY19jNg','UBMk30rjy0o','RqfkrZA_ie0',
             'UItWltVZZmE','h8ctkfSx6R0','cIuiQyfKBTg',
             'j64BBgBGNIU','LjmZ1YMOwws','I9nG-G4B5Bs','W4eKVKwf3rQ,Cw-Wt4xKD2s']
def play_playlist(video_ids):
    # Initialize the Chrome driver
    driver = webdriver.Chrome()
    video_url = f'https://www.youtube.com/watch?v={video_ids}'
    webbrowser.open(url)

play_playlist(video_ids)

# %% [markdown]
# ## Outcome
# The playlist url becomes: https://www.youtube.com/watch?v=2pLT-olgUJs&list=TLGGtidDM-YJzsExMDA3MjAyMg which I added to my youtube playlist called my_better_workout.
#
# Currently on Day 15 of my 180 day journey.  Next on my list is to increase the varitey of physical activities that I use on my fitness journey.
